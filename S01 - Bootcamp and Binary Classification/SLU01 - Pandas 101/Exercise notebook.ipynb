# %% [markdown]
# # SLU1 - Pandas 101: Exercise notebook

# %% [markdown]
# First things first, import:

# %%
import sys

# %%
sys.executable
# Out:
# '/usr/bin/python3'

# %%
sys.path
# Out:
# ['/usr/lib/python36.zip',
#  '/usr/lib/python3.6',
#  '/usr/lib/python3.6/lib-dynload',
#  '',
#  '/usr/lib/python3.6/site-packages',
#  '/usr/local/lib/python3.6/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.6/dist-packages/IPython/extensions',
#  '/home/ines/.ipython']

# %%
# !jupyter kernelspec list
# Out:
# Available kernels:
#   python2    /home/ines/.local/share/jupyter/kernels/python2
#   python3    /usr/local/share/jupyter/kernels/python3

# %%
import pandas as pd
import numpy as np
from hashlib import sha256
import json
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-da6cea8fc3a6> in <module>
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 from hashlib import sha256
#       4 import json
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# In this notebook the following is tested:
#
# - Pandas Series
# - Pandas DataFrames
# - Printing the columns
# - Load a dataset
# - Preview a dataframe
# - Make use of info and describe

# %% [markdown]
# ## Exercise 1: Series
#
# In this first exercise the goal is to get used to creating series.

# %% [markdown]
# #### 1.1) Create a series with the name of the football club champions of 2019:

# %%
# Create a series with the names of the football champions, using the order provided.
# Let pandas generate the index on its own. 
# Don't forget to delete the raise error

football_clubs_list = ['Barcelona', 'Benfica', 'Juventus', 'PSG', 'Manchester City']

# Create a series for the football_clubs, and call it football_clubs_series. 
football_clubs_series = pd.Series(football_clubs_list)

# YOUR CODE HERE
# raise NotImplementedError()

# %%
# run this cell to see the results 
football_clubs_series
# Out:
# 0          Barcelona
# 1            Benfica
# 2           Juventus
# 3                PSG
# 4    Manchester City
# dtype: object

# %%
assert len(football_clubs_series.index ) == 5 
assert ((football_clubs_series.values[3] == 'PSG') & (football_clubs_series.values[-1] =='Manchester City'))
assert (isinstance(football_clubs_series, pd.Series))

# %% [markdown]
# #### 1.2) Create a series for the countries of each football club (using the football clubs as index):

# %%
football_clubs_list = ['Barcelona', 'Benfica', 'Juventus', 'PSG', 'Manchester City']

country_list = ['Spain', 'Portugal', 'Italy', 'France', 'England']

# Create a series which has the football club as index, and the respective country as values. 
country_series = pd.Series(index=football_clubs_list, data=country_list)

# %%
# run this cell to see the results 
country_series
# Out:
# Barcelona             Spain
# Benfica            Portugal
# Juventus              Italy
# PSG                  France
# Manchester City     England
# dtype: object

# %%
assert (isinstance(country_series, pd.Series))
assert(len(country_series==5))
assert(country_series[-3] == 'Italy')
assert(country_series.index[3] == 'PSG')

# %% [markdown]
# #### 1.3) Get an numpy array with the the index of the given series.

# %%
series = pd.Series(['Spain', 'Portugal', 'Italy', 'France', 'England'], 
                          index=['Barcelona', 'Benfica', 'Juventus', 'PSG', 'Manchester City'])

# Get an array with the indexes of the serie.
index_series = np.array(series.index)

# %%
# run this cell to see the results 
index_series
# Out:
# array(['Barcelona', 'Benfica', 'Juventus', 'PSG', 'Manchester City'],
#       dtype=object)

# %%
assert (isinstance(index_series, np.ndarray))
assert(len(index_series==5))
assert(index_series[2] == 'Juventus')

# %% [markdown]
# ## Exercise 2: DataFrames
#
# In this exercise the goal is to create a simple DataFrame.

# %% [markdown]
# #### 2.1) Create a DataFrame with FootballClub/Country/TotalMarketValue columns

# %%
# Create a dataframe with 3 columns: FootballClub, Country, TotalMarketValue. 
# Let pandas create the index itself
# Make sure the columns are in the right order 
# winners_2019 must be the name of the final dataframe.

football_clubs_list = ['Barcelona', 'Benfica', 'Juventus', 'PSG', 'Manchester City']

country_list = ['Spain', 'Portugal', 'Italy', 'France', 'England']

totalmarketvalue_list = [1070.0, 365.50, 745.50, 922.25, 1170.0]

# in one line, build the dataframe, using a dictionary to tell it what should be the column names
# remember to give the columns the right names, or it won't pass the asserts
winners_2019 = pd.DataFrame({
    'FootballClub': football_clubs_list,
    'Country': country_list,
    'TotalMarketValue': totalmarketvalue_list
}, columns = ['FootballClub', 'Country', 'TotalMarketValue'])

# %%
# The expected output is a dataframe with columns named
# "FootballClub", "Country" and "TotalMarketValue", indexed from 0 to 4.
winners_2019
# Out:
#       FootballClub   Country  TotalMarketValue
# 0        Barcelona     Spain           1070.00
# 1          Benfica  Portugal            365.50
# 2         Juventus     Italy            745.50
# 3              PSG    France            922.25
# 4  Manchester City   England           1170.00

# %%
assert(isinstance(winners_2019, pd.DataFrame))
assert(winners_2019.shape == (5, 3))
assert(winners_2019.iloc[3, 1] == 'France')
assert(winners_2019.columns[2] == 'TotalMarketValue')

# %% [markdown]
# #### 2.2) Create a DataFrame with the Country/TotalMarketValue columns, but with FootballClub as row indexes

# %%
# Create a dataframe with columns Country and TotalMarketValue (in that order), but use FootballClub as index
# winners_2019_ind must be the name of the final dataframe.

football_clubs_list = ['Barcelona', 'Benfica', 'Juventus', 'PSG', 'Manchester City']

country_list = ['Spain', 'Portugal', 'Italy', 'France', 'England']

totalmarketvalue_list = [1070.0, 365.50, 745.50, 922.25, 1170.0]

# Use the lists to create Series for Country and TotalMarketValue
# Hint: use the argument index

country_series = pd.Series(country_list, index = football_clubs_list)

totalmarketvalue_series = pd.Series(totalmarketvalue_list, index = football_clubs_list)

# Finally create the DataFrame, using a dictionary. This should only be 1 line of code. 
winners_2019_ind = pd.DataFrame({
    'Country': country_series,
    'TotalMarketValue': totalmarketvalue_series
})

# %%
# run this cell to see the results 
# The expected output is a dataframe with columns named "Country", "TotalMarketValue", indexed with the correct football clubs.
winners_2019_ind
# Out:
#                   Country  TotalMarketValue
# Barcelona           Spain           1070.00
# Benfica          Portugal            365.50
# Juventus            Italy            745.50
# PSG                France            922.25
# Manchester City   England           1170.00

# %%
assert(isinstance(winners_2019_ind, pd.DataFrame))
assert(winners_2019_ind.shape == (5, 2))
assert(winners_2019_ind.index[3] == 'PSG')
assert(winners_2019_ind.columns[1] == 'TotalMarketValue')
backup_winners_2019_ind = winners_2019_ind.copy()

# %% [markdown]
# ## Exercise 3: Load the zomato dataset
#
#
# In this exercise you will load the zomato data set.
#
# You will then preview it and retrieve some information.

# %% [markdown]
# #### 3.1) Load the data set

# %%
# Load the zomato data set
# it is located at data/zomato_restaurants.csv
zomato_df = pd.read_csv('data/zomato_restaurants.csv')

# %%
# print head it to get an idea of what you've just loaded 
zomato_df.head()
# Out:
#          id                      name          locality    city  \
# 0  18487870                   Boa-Bao            Chiado  Lisboa
# 1  18550207                       SOI     Cais do Sodré  Lisboa
# 2   8212998             Ground Burger  Praça de Espanha  Lisboa
# 3  18301225  Amaterasu Pateo do Sushi             Algés  Lisboa
# 4  18605050               Contrabando            Santos  Lisboa
#
#                                             cuisines  establishment  \
# 0  Oriental, Thai, Malaysian, Filipino, Vietnames...  Casual Dining
# 1  Chinese, Oriental, Japanese, Vietnamese, Korea...  Casual Dining
# 2                                   Burger, American  Casual Dining
# 3                                    Sushi, Japanese  Casual Dining
# 4               American, Latin American, BBQ, Steak  Casual Dining
#
#    average_cost_for_two  all_reviews_count  photo_count  has_table_booking  \
# 0                    40               1521         3733                  0
# 1                    45                480         1363                  0
# 2                    40               1430         2337                  0
# 3                    40                676         1094                  0
# 4                    30                372         1117                  1
#
#    has_online_delivery  aggregate_rating  votes  \
# 0                    0               4.9   3943
# 1                    0               4.3   1168
# 2                    0               4.5   3000
# 3                    0               4.5   1615
# 4                    0               4.3    869
#
#                                              timings
# 0  12:00 a 23:00 (Seg, Ter, Qua, Qui, Dom), 12:00...
# 1  12 Noon to 12 Midnight (Mon-Thu, Sun), 12 Noon...
# 2                              12 Noon a 12 Midnight
# 3             12:00 a 15:30, 19:00 a 23:30 (Seg-Dom)
# 4  Seg-Qui, Dom (12 Noon to 11:59 PM), Sex-Sáb (1...

# %%
assert(isinstance(zomato_df, pd.DataFrame))
assert(zomato_df.shape == (600, 14))

# %% [markdown]
# #### 3.2) Load the data set with an index defined

# %%
# Load the zomato data set ans set the index the "id" column 
# (check the documentatio: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html)
# it is located at data/zomato_restaurants.csv
zomato_df_ind = zomato_df.set_index('id', drop=True)

# %%
# print head it to get an idea of what you've just loaded 
zomato_df_ind.head()
# Out:
#                               name          locality    city  \
# id
# 18487870                   Boa-Bao            Chiado  Lisboa
# 18550207                       SOI     Cais do Sodré  Lisboa
# 8212998              Ground Burger  Praça de Espanha  Lisboa
# 18301225  Amaterasu Pateo do Sushi             Algés  Lisboa
# 18605050               Contrabando            Santos  Lisboa
#
#                                                    cuisines  establishment  \
# id
# 18487870  Oriental, Thai, Malaysian, Filipino, Vietnames...  Casual Dining
# 18550207  Chinese, Oriental, Japanese, Vietnamese, Korea...  Casual Dining
# 8212998                                    Burger, American  Casual Dining
# 18301225                                    Sushi, Japanese  Casual Dining
# 18605050               American, Latin American, BBQ, Steak  Casual Dining
#
#           average_cost_for_two  all_reviews_count  photo_count  \
# id
# 18487870                    40               1521         3733
# 18550207                    45                480         1363
# 8212998                     40               1430         2337
# 18301225                    40                676         1094
# 18605050                    30                372         1117
#
#           has_table_booking  has_online_delivery  aggregate_rating  votes  \
# id
# 18487870                  0                    0               4.9   3943
# 18550207                  0                    0               4.3   1168
# 8212998                   0                    0               4.5   3000
# 18301225                  0                    0               4.5   1615
# 18605050                  1                    0               4.3    869
#
#                                                     timings
# id
# 18487870  12:00 a 23:00 (Seg, Ter, Qua, Qui, Dom), 12:00...
# 18550207  12 Noon to 12 Midnight (Mon-Thu, Sun), 12 Noon...
# 8212998                               12 Noon a 12 Midnight
# 18301225             12:00 a 15:30, 19:00 a 23:30 (Seg-Dom)
# 18605050  Seg-Qui, Dom (12 Noon to 11:59 PM), Sex-Sáb (1...

# %%
assert(isinstance(zomato_df_ind, pd.DataFrame))
assert(zomato_df_ind.shape == (600, 13))

# %% [markdown]
# #### 3.3) Get general information about the dataframe

# %%
# Print zomato_df_ind info
# reminder: jupyter just prints out the last output, 
# so you don't need to use a print statement

zomato_df_ind
# Out:
#                                        name                   locality  \
# id
# 18487870                            Boa-Bao                     Chiado
# 18550207                                SOI              Cais do Sodré
# 8212998                       Ground Burger           Praça de Espanha
# 18301225           Amaterasu Pateo do Sushi                      Algés
# 18605050                        Contrabando                     Santos
# 18663838                      Amélia Lisboa           Campo de Ourique
# 18393793  Polpetta - Almondegaria Artesanal                    Arroios
# 18581804                    Jamie's Italian              Príncipe Real
# 8204902                              Siesta                      Algés
# 18570049                        Mez Cais LX      LX Factory, Alcântara
# 18425560                          O Quintal                   Venteira
# 18677130           Zenith Brunch & Cocktail                       Pena
# 18619569            Soão - Taberna Asiática                   Alvalade
# 18551785      Zero Zero - Parque das Nações          Parque das Nações
# 18719249                   The Green Affair                   Saldanha
# 18335531                             Nómada              Campo Pequeno
# 8210567                         Atalho Real              Príncipe Real
# 8202867                                 Psi                       Pena
# 18463068                           SushiNow          Parque das Nações
# 8213530                       The Old House          Parque das Nações
# 8214506                      Ribs & Company            Odivelas Centro
# 18594986                                Kin                   Mouraria
# 8213440                       Sala de Corte              Cais do Sodré
# 18401933                       The B Temple                     Chiado
# 8213881                         Don Costini                   Saldanha
# 8202270               Italy - Lisbona Caffé                   Saldanha
# 18446907                          Heim Cafe                     Santos
# 8203651                        Las Ficheras              Cais do Sodré
# 18275215                           Butchers          Parque das Nações
# 8201924                 Jardim dos Sentidos       Avenida da Liberdade
# ...                                     ...                        ...
# 16548152                              Necci                    Pigneto
# 18017771             TED (Lobster & Burger)                      Prati
# 16556403                       Queen Makeda   Aventino - Circo Massimo
# 16553673                          Maharajah                      Monti
# 16554679                            Panella        Esquilino - Termini
# 16556570                           Sushisen                  Testaccio
# 16553728           L'Antica Birreria Peroni           Fontana di Trevi
# 16556414                          Pizzarium                  Trionfale
# 16556797                       Pastasciutta                      Borgo
# 16556150                  Pizzeria ai Marmi                 Trastevere
# 16553594                         Krishna 13        Esquilino - Termini
# 16555308                        Doppiozeroo                   Ostiense
# 17759043                Da Simo Pane e Vino          Navona - Pantheon
# 16553845                      Da Enzo al 29                 Trastevere
# 16549853                         Cul de Sac          Navona - Pantheon
# 16555005                              Gusto                     Spagna
# 16554241                   La Prosciutteria           Fontana di Trevi
# 16551915                      Come Il Latte                     Veneto
# 16556116                               C1b0                Monte Sacro
# 16549140        La Pergola - Rome Cavalieri  Rome Cavalieri, Trionfale
# 16551780                      Bar Celestino                San Lorenzo
# 16555292                           Maranega            Campo de' Fiori
# 16554302                        Nonna Betta                     Ghetto
# 16551093                        Tre Scalini          Navona - Pantheon
# 16554645                       That's Amore           Fontana di Trevi
# 16551782                         Old Bridge                      Prati
# 16556252                               Said                San Lorenzo
# 16549280                     100 Montaditos                  Farnesina
# 16553285                        Oppio Caffè                   Colosseo
# 17877644           We Food - Eat Love Drink                Policlinico
#
#             city                                           cuisines  \
# id
# 18487870  Lisboa  Oriental, Thai, Malaysian, Filipino, Vietnames...
# 18550207  Lisboa  Chinese, Oriental, Japanese, Vietnamese, Korea...
# 8212998   Lisboa                                   Burger, American
# 18301225  Lisboa                                    Sushi, Japanese
# 18605050  Lisboa               American, Latin American, BBQ, Steak
# 18663838  Lisboa        Desserts, Juices, Healthy Food, Finger Food
# 18393793  Lisboa                           Portuguese, Healthy Food
# 18581804  Lisboa                                            Italian
# 8204902   Lisboa                                            Mexican
# 18570049  Lisboa                                 Mexican, Beverages
# 18425560  Lisboa                Petiscos, Portuguese, Mediterranean
# 18677130  Lisboa    Healthy Food, Vegetarian, Juices, International
# 18619569  Lisboa  Korean, Chinese, Japanese, Indian, Vietnamese,...
# 18551785  Lisboa                                     Pizza, Italian
# 18719249  Lisboa             Contemporary, Healthy Food, Vegetarian
# 18335531  Lisboa                                Sushi, Contemporary
# 8210567   Lisboa                                      Steak, Burger
# 8202867   Lisboa                                         Vegetarian
# 18463068  Lisboa                                    Japanese, Sushi
# 8213530   Lisboa                                            Chinese
# 8214506   Lisboa                            American, Steak, Burger
# 18594986  Lisboa                                Oriental, Beverages
# 8213440   Lisboa                                              Steak
# 18401933  Lisboa                                Burger, Finger Food
# 8213881   Lisboa  Pizza, Burger, Italian, American, Gourmet Fast...
# 8202270   Lisboa                                     Italian, Pizza
# 18446907  Lisboa                            Cafe, Healthy Food, Tea
# 8203651   Lisboa                                 Mexican, Beverages
# 18275215  Lisboa                               Steak, Burger, Grill
# 8201924   Lisboa                           Vegetarian, Healthy Food
# ...          ...                                                ...
# 16548152    Roma                            Cafe, Italian, Desserts
# 18017771    Roma                                    Burger, Seafood
# 16556403    Roma                     Fusion, Burger, Asian, Italian
# 16553673    Roma                                             Indian
# 16554679    Roma                    Cafe, Bakery, Desserts, Italian
# 16556570    Roma                             Sushi, Japanese, Asian
# 16553728    Roma                     Burger, German, Roman, Italian
# 16556414    Roma                                 Street Food, Pizza
# 16556797    Roma                                 Home-made, Italian
# 16556150    Roma                                       Pizza, Roman
# 16553594    Roma                                             Indian
# 16555308    Roma                 Cafe, Pizza, Tavola Calda, Italian
# 17759043    Roma                                             Panini
# 16553845    Roma                                     Roman, Italian
# 16549853    Roma                                            Italian
# 16555005    Roma                             Pizza, Burger, Italian
# 16554241    Roma                                      Tavola Fredda
# 16551915    Roma                        Ice Cream, Crepes, Desserts
# 16556116    Roma                                   Burger, American
# 16549140    Roma                             Haute Cuisine, Italian
# 16551780    Roma                                Cafe, Tavola Fredda
# 16555292    Roma                        Cafe, Pizza, Roman, Italian
# 16554302    Roma             Jewish, Roman, Italian, Middle Eastern
# 16551093    Roma                    Roman, Ice Cream, Cafe, Italian
# 16554645    Roma                     Pizza, Roman, Seafood, Italian
# 16551782    Roma                                          Ice Cream
# 16556252    Roma                                  Desserts, Italian
# 16549280    Roma                                    Panini, Spanish
# 16553285    Roma                    Cafe, Burger, American, Italian
# 17877644    Roma                                 Steak, BBQ, Burger
#
#            establishment  average_cost_for_two  all_reviews_count  \
# id
# 18487870   Casual Dining                    40               1521
# 18550207   Casual Dining                    45                480
# 8212998    Casual Dining                    40               1430
# 18301225   Casual Dining                    40                676
# 18605050   Casual Dining                    30                372
# 18663838            Café                    20                731
# 18393793   Casual Dining                    25                514
# 18581804   Casual Dining                    40                647
# 8204902    Casual Dining                    50               1214
# 18570049   Casual Dining                    30                401
# 18425560   Casual Dining                    35                663
# 18677130     Quick Bites                    25                447
# 18619569   Casual Dining                    60                309
# 18551785   Casual Dining                    50                569
# 18719249   Casual Dining                    20                172
# 18335531   Casual Dining                    60                474
# 8210567    Casual Dining                    45               1470
# 8202867    Casual Dining                    30                687
# 18463068   Casual Dining                    45                400
# 8213530      Fine Dining                    60                582
# 8214506    Casual Dining                    25                898
# 18594986   Casual Dining                    40                203
# 8213440    Casual Dining                    60                555
# 18401933   Casual Dining                    30                988
# 8213881    Casual Dining                    25                534
# 8202270    Casual Dining                    35                759
# 18446907            Café                    20                557
# 8203651    Casual Dining                    40               1115
# 18275215   Casual Dining                    40               1012
# 8201924    Casual Dining                    35                580
# ...                  ...                   ...                ...
# 16548152   Casual Dining                    50                 38
# 18017771   Casual Dining                    65                 26
# 16556403             Pub                    40                 35
# 16553673   Casual Dining                    60                 36
# 16554679            Café                    20                 34
# 16556570   Casual Dining                    50                 23
# 16553728   Casual Dining                    60                 28
# 16556414     Quick Bites                    20                 37
# 16556797     Quick Bites                    10                 29
# 16556150        Pizzeria                    50                 39
# 16553594   Casual Dining                    40                 29
# 16555308          Bistro                    65                 49
# 17759043     Quick Bites                    20                  5
# 16553845   Casual Dining                    50                 26
# 16549853   Casual Dining                    40                 27
# 16555005   Casual Dining                    70                 38
# 16554241   Casual Dining                    40                 24
# 16551915  Ice Cream Shop                     6                 36
# 16556116          Bistro                    40                 37
# 16549140     Fine Dining                   300                 16
# 16551780     Bar - Caffe                    10                 61
# 16555292   Casual Dining                    50                 22
# 16554302   Casual Dining                    60                 21
# 16551093   Casual Dining                    70                 26
# 16554645   Casual Dining                    70                 24
# 16551782  Ice Cream Shop                     6                 35
# 16556252          Bistro                    60                 27
# 16549280   Casual Dining                    20                 42
# 16553285            Café                    10                 28
# 17877644   Casual Dining                    40                 18
#
#           photo_count  has_table_booking  has_online_delivery  \
# id
# 18487870         3733                  0                    0
# 18550207         1363                  0                    0
# 8212998          2337                  0                    0
# 18301225         1094                  0                    0
# 18605050         1117                  1                    0
# 18663838         1820                  0                    0
# 18393793         1121                  1                    0
# 18581804         1920                  0                    0
# 8204902          2144                  0                    0
# 18570049          716                  1                    0
# 18425560         1819                  1                    0
# 18677130         1102                  0                    0
# 18619569          933                  0                    0
# 18551785         1141                  0                    0
# 18719249          390                  1                    0
# 18335531         1369                  1                    0
# 8210567          2466                  0                    0
# 8202867          1701                  1                    0
# 18463068          902                  0                    0
# 8213530          1489                  0                    0
# 8214506          2064                  0                    0
# 18594986          648                  1                    0
# 8213440          1447                  0                    0
# 18401933         1906                  1                    0
# 8213881           960                  1                    0
# 8202270          1422                  1                    0
# 18446907         1155                  0                    0
# 8203651          2006                  1                    0
# 18275215         1772                  0                    0
# 8201924          1241                  1                    0
# ...               ...                ...                  ...
# 16548152           59                  0                    0
# 18017771           84                  0                    0
# 16556403          150                  0                    0
# 16553673           35                  0                    0
# 16554679           72                  0                    0
# 16556570          207                  0                    0
# 16553728          118                  0                    0
# 16556414         1282                  0                    0
# 16556797           74                  0                    0
# 16556150          231                  0                    0
# 16553594           84                  0                    0
# 16555308          285                  0                    0
# 17759043          124                  0                    0
# 16553845          218                  0                    0
# 16549853          361                  0                    0
# 16555005           31                  0                    0
# 16554241          699                  0                    0
# 16551915          253                  0                    0
# 16556116          173                  0                    0
# 16549140           68                  0                    0
# 16551780           45                  0                    0
# 16555292           70                  0                    0
# 16554302          102                  0                    0
# 16551093          396                  0                    0
# 16554645          166                  0                    0
# 16551782          299                  0                    0
# 16556252           48                  0                    0
# 16549280          937                  0                    0
# 16553285          141                  0                    0
# 17877644           70                  0                    0
#
#           aggregate_rating  votes  \
# id
# 18487870               4.9   3943
# 18550207               4.3   1168
# 8212998                4.5   3000
# 18301225               4.5   1615
# 18605050               4.3    869
# 18663838               4.6   1799
# 18393793               4.6   1184
# 18581804               4.4   1478
# 8204902                4.1   3102
# 18570049               4.1    928
# 18425560               4.5   1385
# 18677130               4.6   1152
# 18619569               4.7    871
# 18551785               4.4   1303
# 18719249               4.5    493
# 18335531               4.9   1248
# 8210567                4.7   3603
# 8202867                4.6   1785
# 18463068               4.5   1018
# 8213530                4.7   1231
# 8214506                4.5   2006
# 18594986               4.5    534
# 8213440                4.7   1211
# 18401933               4.6   2304
# 8213881                4.0   1044
# 8202270                4.4   1807
# 18446907               4.6   1317
# 8203651                4.1   2513
# 18275215               4.6   2411
# 8201924                4.6   1423
# ...                    ...    ...
# 16548152               4.3     57
# 18017771               4.1     29
# 16556403               4.2     44
# 16553673               4.4     62
# 16554679               4.3     53
# 16556570               4.4     36
# 16553728               4.3     51
# 16556414               4.6     52
# 16556797               4.5     48
# 16556150               4.2     60
# 16553594               4.2     49
# 16555308               4.4     66
# 17759043               3.8      9
# 16553845               4.5     55
# 16549853               4.6     54
# 16555005               4.2     56
# 16554241               4.5     47
# 16551915               4.5     56
# 16556116               4.3     50
# 16549140               4.4     31
# 16551780               4.3     65
# 16555292               4.2     27
# 16554302               4.4     41
# 16551093               4.5     32
# 16554645               4.4     47
# 16551782               4.3     53
# 16556252               4.4     40
# 16549280               4.3     46
# 16553285               4.2     46
# 17877644               4.5     24
#
#                                                     timings
# id
# 18487870  12:00 a 23:00 (Seg, Ter, Qua, Qui, Dom), 12:00...
# 18550207  12 Noon to 12 Midnight (Mon-Thu, Sun), 12 Noon...
# 8212998                               12 Noon a 12 Midnight
# 18301225             12:00 a 15:30, 19:00 a 23:30 (Seg-Dom)
# 18605050  Seg-Qui, Dom (12 Noon to 11:59 PM), Sex-Sáb (1...
# 18663838                            09:00 a 21:00 (Seg-Dom)
# 18393793  12:00 a 15:00, 19:30 a 22:30 (Seg-Sáb),Fechado...
# 18581804  12 Noon to 11 PM (Mon-Thu, Sun), 12 Noon to 12...
# 8204902   12 Noon to 1 AM (Mon-Fri), 12:30 PM to 1 AM (S...
# 18570049  12:00 – 24:00 (Mon, Tue, Wed, Thu, Sun), 12:00...
# 18425560                 12:30 PM to 3 PM, 7:30 PM to 11 PM
# 18677130                                       9 AM to 7 PM
# 18619569  12:30 PM a 3:30 PM, 7:30 PM a 11 PM (Seg-Qui),...
# 18551785                             12 Noon to 12 Midnight
# 18719249                            12:00 a 23:00 (Seg-Dom)
# 18335531  12:30 PM a 3 PM, 7:30 PM a 11 PM (Seg-Qui), 12...
# 8210567   12 Noon a 12 Midnight (Seg-Qua, Dom), 12 Noon ...
# 8202867   12:30 PM to 3:30 PM, 7:30 PM to 10:30 PM (Mon-...
# 18463068  12:30 PM to 3 PM, 7:30 PM to 11 PM (Ter-Sex, D...
# 8213530                        12 Noon a 3 PM, 7 PM a 11 PM
# 8214506   12 Noon a 3 PM, 7 PM a 11 PM (Ter-Qui), 12 Noo...
# 18594986          8 PM to 12 Midnight (Mon-Sat), Sun Closed
# 8213440   12:00 a 16:00, 19:00 a 24:00 (Seg-Qui),12:00 a...
# 18401933                      Seg-Dom (12 Noon to 11:59 PM)
# 8213881   12:00 a 16:00, 19:00 a 23:00 (Seg, Ter, Qua, D...
# 8202270                              12 Noon to 12 Midnight
# 18446907        09:00 – 15:00 (Mon),09:00 – 18:00 (Tue-Sun)
# 8203651   11 AM to 1 AM (Mon-Thu, Sun), 11 AM to 2 AM (F...
# 18275215  12:00 a 15:00, 19:00 a 23:00 (Seg-Qua),12:00 a...
# 8201924   12:00 a 15:00, 19:00 a 22:30 (Seg-Sex),12:30 a...
# ...                                                     ...
# 16548152                           08:00 to 02:00 (Mon-Sun)
# 18017771                           12:00 to 02:00 (Mon-Sun)
# 16556403  12:00 to 15:00, 18:00 to 02:00 (Mon-Sat),12:30...
# 16553673           12:00 to 15:00, 19:00 to 23:00 (Mon-Sun)
# 16554679                           08:00 to 23:00 (Mon-Sun)
# 16556570  Closed (Mon),12:30 to 14:30, 19:30 to 23:00 (T...
# 16553728              12:00 to 24:00 (Mon-Sat),Closed (Sun)
# 16556414  11:00 to 22:00 (Mon-Sat),12:00 to 16:00, 18:00...
# 16556797                           10:30 to 18:30 (Mon-Sun)
# 16556150  19:00 to 02:00 (Mon, Tue, Thu, Fri, Sat, Sun),...
# 16553594           11:00 to 15:30, 19:00 to 23:30 (Mon-Sun)
# 16555308      07:00 to 01:30 (Mon-Sat),12:30 to 01:30 (Sun)
# 17759043  11:00 to 21:00 (Mon, Tue, Wed, Thu, Sun), 11:0...
# 16553845  12:30 to 15:00, 19:30 to 23:00 (Mon-Sat),Close...
# 16549853                           12:00 to 00:30 (Mon-Sun)
# 16555005                           12:00 to 23:00 (Mon-Sun)
# 16554241                           11:30 to 23:30 (Mon-Sun)
# 16551915  11:00 to 24:00 (Mon-Thu),11:00 to 01:00 (Fri-S...
# 16556116                           12:30 to 02:00 (Mon-Sun)
# 16549140        Closed (Mon, Sun), 19:30 to 23:30 (Tue-Sat)
# 16551780                           06:30 to 01:00 (Mon-Sun)
# 16555292                           08:00 to 02:00 (Mon-Sun)
# 16554302  12:00 to 23:00 (Mon, Wed, Thu, Fri, Sat, Sun),...
# 16551093                           11:00 to 23:00 (Mon-Sun)
# 16554645                           12:00 to 24:00 (Mon-Sun)
# 16551782      09:00 to 24:00 (Mon-Sat),14:00 to 02:00 (Sun)
# 16556252  10:00 to 00:30 (Mon-Thu),10:00 to 01:30 (Fri-S...
# 16549280                           11:00 to 24:00 (Mon-Sun)
# 16553285                           07:00 to 02:00 (Mon-Sun)
# 17877644              Closed (Mon),11:00 to 02:00 (Tue-Sun)
#
# [600 rows x 13 columns]

# %%
# How many columns of type "int" exists?

count_int = sum(zomato_df_ind.dtypes == int)

# %%
hash_count = 'e7f6c011776e8db7cd330b54174fd76f7d0216b612387a5ffcfb81e6f0919683'

assert (hash_count == sha256(str(count_int).encode()).hexdigest())

# %% [markdown]
# #### 3.4) Preview the top 7 entries

# %%
# Print the top 7 entries of zomato_df_ind

zomato_df_ind_top = zomato_df_ind.head(7)

# %%
assert (zomato_df_ind_top.shape == (7,13))

# %% [markdown]
# #### 3.5) Preview the bottom 3 entries

# %%
# Print the bottom 3 entries of zomato_df_ind

zomato_df_ind_bottom = zomato_df_ind.tail(3)

# %%
assert (zomato_df_ind_bottom.shape == (3,13))

# %% [markdown]
# ###### 3.6) Use a method to determine all the types os data in zomato_df_ind

# %%
# Print the type of data in zomato_df_ind

zomato_df_ind.dtypes
# Out:
# name                     object
# locality                 object
# city                     object
# cuisines                 object
# establishment            object
# average_cost_for_two      int64
# all_reviews_count         int64
# photo_count               int64
# has_table_booking         int64
# has_online_delivery       int64
# aggregate_rating        float64
# votes                     int64
# timings                  object
# dtype: object

# %% [markdown]
# #### 3.7) Print the number of rows and the number of columns

# %%
# Get the nr_rows and nr_cols from zomato_df_ind, using a method

nr_rows = zomato_df_ind.shape[0]
nr_cols = zomato_df_ind.shape[1]

print("There are {} rows and {} columns.".format(nr_rows, nr_cols))
# Out:
# There are 600 rows and 13 columns.

# %%
assert (nr_rows == 600 )
assert (nr_cols == 13 )

# %% [markdown]
# #### 3.8) Get the array of column names

# %%
# Create an array with the column names of zomato_df_ind.
# there is, as always, a method for this 

zomato_df_columns = zomato_df_ind.columns

# %%
print(zomato_df_columns)
# Out:
# Index([u'name', u'locality', u'city', u'cuisines', u'establishment',
#        u'average_cost_for_two', u'all_reviews_count', u'photo_count',
#        u'has_table_booking', u'has_online_delivery', u'aggregate_rating',
#        u'votes', u'timings'],
#       dtype='object')

# %% [markdown]
# The expected output is an array with 'name', 'locality', 'city', 'cuisines', 'establishment','average_cost_for_two', 'all_reviews_count', 'photo_count', 'has_table_booking', 'has_online_delivery', 'aggregate_rating', 'votes','timings'.

# %%
assert (zomato_df_columns[1] == 'locality' )
assert (len(zomato_df_columns) == 13)

# %% [markdown]
# #### 3.9) Making use of describe() what is the standard deviation value of the votes?

# %%
# Print zomato_df_ind describe

zomato_df_ind.describe()
# Out:
#        average_cost_for_two  all_reviews_count  photo_count  \
# count            600.000000         600.000000   600.000000
# mean            2327.295000         170.311667   450.480000
# std             7716.362878         258.212511   621.216338
# min                0.000000           0.000000     0.000000
# 25%               20.000000           5.000000    12.750000
# 50%               40.000000          78.000000   223.000000
# 75%              100.000000         241.250000   616.750000
# max            50000.000000        2640.000000  4464.000000
#
#        has_table_booking  has_online_delivery  aggregate_rating        votes
# count         600.000000           600.000000        600.000000   600.000000
# mean            0.118333             0.120000          3.910667   367.405000
# std             0.323272             0.325233          1.263836   594.930687
# min             0.000000             0.000000          0.000000     0.000000
# 25%             0.000000             0.000000          3.900000    12.750000
# 50%             0.000000             0.000000          4.300000   143.500000
# 75%             0.000000             0.000000          4.500000   461.750000
# max             1.000000             1.000000          4.900000  5703.000000

# %%
# Manually input the standard deviation value of the votes
# yep, that simple. No tricks here :) 

votes_std = 594.930687

# %%
print("Standard deviation value of the votes is {}.".format(votes_std))
# Out:
# Standard deviation value of the votes is 594.930687.

# %%
assert 594 < votes_std < 595
